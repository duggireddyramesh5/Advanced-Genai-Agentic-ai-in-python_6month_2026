# %%
'Welcome'
# Out:
# 'Welcome'

# %%
a = 2
b= 4
c = a + b
print(c)
# Out:
# 6

# %%
test = 1
test
print(test)

# %%
nit = 1010
nit
# Out:
# 1010

# %%
nit = 1020
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 nit = 1020
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit1 = 1030
nit1
# Out:
# 1030

# %%
1nit = 2040
1nit
# Out:
#   Cell In[4], line 1
#     1nit = 2040
#     ^
# SyntaxError: invalid decimal literal

# %%
nit@ = 100
nit@
# Out:
#   Cell In[5], line 1
#     nit@ = 100
#          ^
# SyntaxError: invalid syntax

# %%
_nit = 4050
_nit
# Out:
# 4050

# %%
true = 4
true
# Out:
# 4

# %%
True = 5
True
# Out:
#   Cell In[8], line 1
#     True = 5
#     ^
# SyntaxError: cannot assign to True

# %%
_
# Out:
# '{"dataframes": [], "user": "duggi"}'

# %%
_nit = ramesh
_nit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 _nit = ramesh
#       2 _nit
#
# NameError: name 'ramesh' is not defined

# %%
_nit = "ramesh"
_nit
# Out:
# 'ramesh'

# %%
_
# Out:
# '{"dataframes": [], "user": "duggi"}'

# %%
_nit = 5
_nit
# Out:
# 5

# %%
# Out:
# '{"dataframes": [], "user": "duggi"}'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# 1020 = nit
# nit

# %%
i = 5
i
type(i)
id(i)
# Out:
# 140716634973224

# %% [markdown]
# f = 110.45
# f

# %%
f = 290.05
f
type(f)
# Out:
# float

# %%
gold_price = 14800.78
gold_price
type(gold_price)
# Out:
# float

# %%
10 + 5
10 - 5
10 * 5
# Out:
# 50

# %%
print(10 + 5)
print(10 - 5)
print(10 * 5)
# Out:
# 15
# 5
# 50

# %%
f1 = 2.4e1
f1
type(f1)
# Out:
# float

# %%
f2 = 3.5e3
f2
# Out:
# 3500.0

# %%
f3 = 3.2E3
f3
# Out:
# 3200.0

# %%
# boolean value

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False / True #float division
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# # Complex ---> no other programming language has complex data type except python

# %% [markdown]
# # Complex  --> real part & imaginary part

# %%
c = 10 + 20j # 10 - real part & 20 imagenary part where j = square root  of -1
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
b = True
b1 = False
c = b + b1
c
# Out:
# 1

# %%
b = False
type(b)
# Out:
# bool

# %%
c = 1 + 2j
c1 = 3 + 4j
print(c)
print(c1)
# Out:
# (1+2j)
# (3+4j)

# %%
c + c1
# Out:
# (4+6j)

# %%
#string

# %%
'''welcome naresh it '''
# Out:
# 'welcome naresh it '

# %%
"welcome naresh it"
# Out:
# 'welcome naresh it'

# %%
s = 'python'
s
# Out:
# 'python'

# %%
s1 = 'welcome to genai agentic ai'
s1[3]
# Out:
# 'c'

# %%
s1[5]
# Out:
# 'm'

# %%
s1[11]
# Out:
# 'g'

# %%
s1[78]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 s1[78]
#
# IndexError: string index out of range

# %%
s[-3]
# Out:
# 'h'

# %%
s2 = 'nareshtechnology'
s2
# Out:
# 'nareshtechnology'

# %%
s2[:]
# Out:
# 'nareshtechnology'

# %%
len(s2)
# Out:
# 16

# %%
s2[3:]
# Out:
# 'eshtechnology'

# %%
s2[0:]
# Out:
# 'nareshtechnology'

# %%
s2[:6]
# Out:
# 'naresh'

# %%
s2[:100]
# Out:
# 'nareshtechnology'

# %%
s3 = 'welcometeam'
s3
# Out:
# 'welcometeam'

# %%
s3[1:5]
# Out:
# 'elco'

# %%
s3[1:8:3]
# Out:
# 'eot'

# %%
s3
# Out:
# 'welcometeam'

# %%
s3[::1]
# Out:
# 'welcometeam'

# %%
s3[::2]
# Out:
# 'wloeem'

# %%
s3[::-1]
# Out:
# 'maetemoclew'

# %%
s3[::-2]
# Out:
# 'meeolw'

# %%
s3[2:5]
# Out:
# 'lco'

# %% [markdown]
#  # python typecasting

# %%
- car()  -- car function without argument
- asian_cars('tata','toyota')  -- car function with 2 arguments | type of argument string
- german_cars('audi','bmw','ferarai','vw') - germ car with 4 arguments

# %% [markdown]
# # we will type cast all other data type to integer

# %%
int(2.3)
# Out:
# 2

# %%
int(2.3, 4.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 int(2.3, 4.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(1 + 2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 int(1 + 2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # other data types to float

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('20')
# Out:
# 20.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # all other datatypes to bool

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(4)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
val1 = 20
val1
# Out:
# 20

# %%
import sys
sys.getsizeof(val1)
# Out:
# 28

# %%
val1 = [20 ,35 ,40, 60, 45,29,14]
val1
# Out:
# [20, 35, 40, 60, 45, 29, 14]

# %%
sys.getsizeof(val1)
# Out:
# 88

# %%
sys.getsizeof(val1)
# Out:
# 120

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3,4.5)
# Out:
# (2.3+4.5j)

# %%
complex(23,4.5)
# Out:
# (23+4.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True, False)
# Out:
# (1+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10 ,'20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 complex(10 ,'20')
#
# TypeError: complex() second arg can't be a string

# %%
complex('10', 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 complex('10', 20)
#
# TypeError: complex() can't take second arg if first is a string

# %%
str(100)
# Out:
# '100'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
str(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 str(2,3)
#
# TypeError: str() argument 'encoding' must be str, not int

# %%
str('abc')
# Out:
# 'abc'

# %%
complex('test')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 complex('test')
#
# ValueError: complex() arg is a malformed string

# %% [markdown]
# # python basic operator

# %% [markdown]
# # Arithmetic Operatot , Assignment Operatot , Relational Operatot & Logical Operatot

# %% [markdown]
# # Arithmetic Operator

# %%
x1, y1 = 10,5
x1 + y1
# Out:
# 15

# %%
x1 - y1
# Out:
# 5

# %%
x1 * y1
# Out:
# 50

# %%
x1 / y1
# Out:
# 2.0

# %%
x1 // y1
# Out:
# 2

# %%
x1 % y1
# Out:
# 0

# %%
2 * 3
# Out:
# 6

# %%
2 ** 3
# Out:
# 8

# %%
# Assignment Operator

# %%
x = 2 
x = x + 2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x *= 2
x
# Out:
# 12

# %%
x * = 2
x
# Out:
#   Cell In[149], line 1
#     x * = 2
#         ^
# SyntaxError: invalid syntax

# %%
x //= 2
x
# Out:
# 6

# %%
x %= 2
x
# Out:
# 0

# %% [markdown]
# # Unary Operator

# %%
n = 7
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# # Relational Operator

# %%
a = 5
b = 6
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
b < a
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a = b

# %%
a == b
# Out:
# True

# %%
c = 5
d = 7
c == d
# Out:
# False

# %%
print(c)
print(d)
# Out:
# 5
# 7

# %%
c != d
# Out:
# True

# %%
c = d

# %%
c != d
# Out:
# False

# %%
print(c)
print(d)
# Out:
# 7
# 7

# %%
c > d
# Out:
# False

# %%
c == d
# Out:
# True

# %%
c < d
# Out:
# False

# %%
c <= d
# Out:
# True

# %% [markdown]
# # Logical Operator

# %%
a = 5
b1 = 4

# %%
a < 8
# Out:
# True

# %%
b1 < 5
# Out:
# True

# %%
a < 8 and b1 < 5
# Out:
# True

# %%
a < 8 or b1 < 5
# Out:
# True

# %%
a < 8 or b1 > 5
# Out:
# True

# %%
b1 = 4
b1
# Out:
# 4

# %%
x = True
x
# Out:
# True

# %%
-x
# Out:
# -1

# %%
not x
# Out:
# False

# %%
# BODMAS ( bracket Order Dimension Multiply Addition

# %%
2 + 3 * 5 -6
# Out:
# 11

# %%
3 + (2 * 5 ) - 1
# Out:
# 12

# %%
5 + 2 - 1 * 6 % 3
# Out:
# 7

# %%
num1 = 20
num2 = 30

add = num1 + num2
print(add)
# Out:
# 50

# %% [markdown]
# # print result with string

# %%
num1 = 20
num2 = 30
add = num1+num2
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 20 and 30 is= 50

# %%
# heelucination means confusion . Because we are not writing a neighboring word. For example
# if the user is asking apple to LLM then LLM is confusing either apple fruit Or apple phone
